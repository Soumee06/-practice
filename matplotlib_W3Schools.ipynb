# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumee06/-practice/blob/main/matplotlib_W3Schools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt # most of things in matplotlibb lie under the pyplot submodule

# %% [markdown]
# Draw a line in a diagram from position (0,0) to position (6,250):

# %%
import numpy as np
x =np.array([0,6])
y=np.array([0,250])
plt.plot(x,y)
plt.show()

# %% [markdown]
# Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.

# %% [markdown]
# Draw a line in a diagram from position (1, 3) to position (8, 10):

# %%
x_point=np.array([1,8]) 
y_point=np.array([3,10])
plt.plot(x_point,y_point)
plt.show()

# %% [markdown]
# Plotting Without Line
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
x_point=np.array([1,8]) 
y_point=np.array([3,10])
plt.plot(x_point,y_point,"o")
plt.show()

# %%
#Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
x_point=np.array([1,2,6,8]) 
y_point=np.array([3,8,1,10])
plt.plot(x_point,y_point)
plt.show()

# %% [markdown]
# Default X-Points
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.

# %%
y_point=np.array([3,8,1,10])
plt.plot(y_point)
plt.show()

# %% [markdown]
# Markers
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
y_point=np.array([3,8,1,10])
plt.plot(y_point, marker="o")
plt.show()

# %% [markdown]
# Format Strings fmt
# You can use also use the shortcut string notation parameter to specify the marker.
#
# This parameter is also called fmt, and is written with this syntax:
#
# marker|line|color

# %%
y_point=np.array([3,8,1,10])
plt.plot(y_point, "o:b",ms=12,mec="r",mfc="b") #ms denotes marker size,mec denotes marker edge color
plt.show()

# %% [markdown]
# Linestyle
# You can use the keyword argument linestyle, or shorter ls, to change the style of the plotted line:

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dashed',linewidth=12)
plt.show()

# %%
#Multiple Lines
#You can plot as many lines as you like by simply adding more plt.plot() functions:

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1,"o:r")
plt.plot(y2,"o:b")

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1,"o:b", x2, y2,"o:r")
plt.show()

# %% [markdown]
# Create Labels for a Plot

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(x, y)

plt.title("Sports Watch data",font1,loc="center") #You can use the loc parameter in title() to position the title.
plt.xlabel("Average Pulse",fontdict=font2)
plt.ylabel("Calorie Burnage",fontdict=font2)

plt.grid(color="r",ls="--",lw=1)#With Pyplot, you can use the grid() function to add grid lines to the plot.
#plt.gris(axis="x") specifying the axis gridline which you want to show
plt.show()

# %% [markdown]
# SUBPLOTS

# %% [markdown]
# The subplot() Function
# The subplot() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.
#
# plt.subplot(1, 2, 1)
# the figure has 1 row, 2 columns, and this plot is the first plot.

# %%
#plot1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1,2,1)
plt.plot(x,y,"o:b")

#plot2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y,"o:r")

plt.show()

# %% [markdown]
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:

# %%
#plot1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,1,1)
plt.plot(x,y,"o:b")

#plot2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y,"o:r")

plt.show()

# %%
#plot1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2,2,1)
plt.plot(x,y,"o:b")
plt.title("first")
#plot2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y,"o:r")
plt.title("second")


#plot3
x = np.array([-1, -2,1, 2 ])
y = np.array([-10, 20, -30, 40])

plt.subplot(2, 2, 3)
plt.plot(x,y,"o:r")
plt.title("third")
#plot4
x = np.array([10, 11, 12, 13])
y = np.array([1, 2, 3, 4])

plt.subplot(2, 2, 4)
plt.plot(x,y,"o:b")
plt.title("fourth")

plt.suptitle("The Graph")
plt.show() #You can add a title to the entire figure with the suptitle() function:

# %% [markdown]
# #scatter plot
# Creating Scatter Plots
# With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999',alpha=0.5) #alpha parameter is for transparency of dots

plt.show()

# %% [markdown]
# #Creating Bars
# With Pyplot, you can use the bar() function to draw bar graphs:

# %%
#The bar() function takes arguments that describes the layout of the bars.

#The categories and their values represented by the first and second argument as arrays.

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
X=["Male","Female"]
Y=[40,60]

plt.bar(X,Y,color="r",width=0.5)
plt.show()

# %%
X=["Male","Female"]
Y=[40,60]

plt.barh(X,Y,color="g",height=0.5)
plt.show()

# %% [markdown]
# #Histogram
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"] #The label parameter must be an array with one label for each wedge:
myexplode = [0.2, 0, 0, 0] #Pull the "Apples" wedge 0.2 from the center of the pie:
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y, labels = mylabels,startangle=90,explode=myexplode,shadow=True,colors=mycolors)#The startangle parameter is defined with an angle in degrees, default angle is 0:
plt.legend(title="four fruits")
plt.show() 

#The explode parameter, if specified, and not None, must be an array with one value for each wedge.

#Each value represents how far from the center each wedge is displayed:
